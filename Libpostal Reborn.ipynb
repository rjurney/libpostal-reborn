# %%
import json
import os

import pandas as pd
from postal.parser import parse_address

from utils import to_dict

# %%
# Display all columns of tables, with scrolling
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Libpostal, Reborn!
#
# This notebook reproduces the code examples from the blog post Libpostal, Reborn!
#
# ## Structured Address Matching
#
# Let's parse two similar addresses to see how Libpostal is useful for address matching.

# %%
address_a = "#03-28, 400 Orchard Rd, 238875 SG"
address_b = "400 Orchard Tower #03-28 Orchard Road, Singapore, 238875 Singapore"

# %%
parsed_a = parse_address(address_a)
parsed_a
# Out:
# [('#03-28', 'unit'),
#  ('400', 'house_number'),
#  ('orchard rd', 'road'),
#  ('238875', 'postcode'),
#  ('sg', 'country')]

# %%
# A utility for pretty printing
print(
    json.dumps(
        to_dict(parsed_a),
        indent=4,
        sort_keys=True,
    )
)
# Out:
# {
#     "country": "sg",
#     "house_number": "400",
#     "postcode": "238875",
#     "road": "orchard rd",
#     "unit": "#03-28"
# }

# %%
parsed_b = parse_address(address_b)
parsed_b
# Out:
# [('400', 'house_number'),
#  ('orchard tower', 'road'),
#  ('#03-28', 'unit'),
#  ('orchard road', 'road'),
#  ('singapore', 'city'),
#  ('238875', 'postcode'),
#  ('singapore', 'country')]

# %%
# A utility for pretty printing
print(
    json.dumps(
        to_dict(parsed_b),
        indent=4,
        sort_keys=True,
    )
)
# Out:
# {
#     "city": "singapore",
#     "country": "singapore",
#     "house_number": "400",
#     "postcode": "238875",
#     "road": [
#         "orchard tower",
#         "orchard road"
#     ],
#     "unit": "#03-28"
# }

# %% [markdown]
# ### How similar are the two parsed addresses?
#
# How similar are the parsed results in literal terms? Three of them are exactly the same.

# %%
intersect = set(parsed_a).intersection(set(parsed_b))
intersect
# Out:
# {('#03-28', 'unit'), ('238875', 'postcode'), ('400', 'house_number')}

# %% [markdown]
# ### How similar are the parsed addresses semantically?
#
# When we take into account commonalities like abbreviations and missing values, how similar are they?

# %%
# What is unique to address a?
set(parsed_a) - intersect
# Out:
# {('orchard rd', 'road'), ('sg', 'country')}

# %%
# What is unique to address b?
set(parsed_b) - intersect
# Out:
# {('orchard road', 'road'),
#  ('orchard tower', 'road'),
#  ('singapore', 'city'),
#  ('singapore', 'country')}

# %% [markdown]
# ### Logical Results
#
# There are two road names once `orchard tower` is parsed as a `road`, and `singapore` is both a `city` and `country`. `sg` and `singapore` match semantically. Libpostal doesn't do the matching for you, that is up to you, but it gives you a huge headstart!

# %% [markdown]
# # Exploring Senzing's New Validation Dataset
#
# Senzing created a dataset of 12K validation records, which we pull from Github below. Let's check it out!

# %%
TEST_DATA_PATH = "data/test_data.csv"
TEST_DATA_URL = "https://github.com/Senzing/libpostal-data/raw/main/files/tests/v1.1.0/test_data.csv"

if not os.path.exists(TEST_DATA_PATH):
    test_df = pd.read_csv(TEST_DATA_URL)
    test_df.to_csv(TEST_DATA_PATH)
else:
    test_df = pd.read_csv(TEST_DATA_PATH)

test_df = test_df.drop(columns=['Unnamed: 0'])

# %%
test_df.head(20)
# Out:
#     record_id                                       full_address  \
# 0           1  Black Alliance for Just Immigration 660 Nostra...
# 1           2  Planned Parenthood, 44 Court St, 6th Floor, Br...
# 2           3  Congresswoman Yvette Clarke 222 Lenox Road, St...
# 3           4  ACLU DC P.O. Box 11637 Washington, DC 20008 Un...
# 4           5  Make the Road New York 92-10 Roosevelt Avenue ...
# 5           6               Do the Right Thing Way, Bed-Stuy, BK
# 6           7                                book stores near me
# 7           8                   theatres in Fort Greene Brooklyn
# 8           9  Barboncino 781 Franklin Ave Crown Heights Broo...
# 9          10              103 BEAL PKWY SE, FT WALTON BEACH, FL
# 10         11                               Canal Rd, Deltona FL
# 11         12                 123 Main St # 456 Oakland CA 94789
# 12         13               123 Main St Apt 456 Oakland CA 94789
# 13         14              123 Main St Apt #456 Oakland CA 94789
# 14         15           123 Main St Apt No. 456 Oakland CA 94789
# 15         16                                    whole foods nyc
# 16         17                                 921 83 street, nyc
# 17         18                                         30 w 26 st
# 18         19                    30 West 26th Street Sixth Floor
# 19         20                                30 W 26th St 6th Fl
#
#                                   house house_number                    road  \
# 0   black alliance for just immigration          660            nostrand ave
# 1                    planned parenthood           44                court st
# 2           congresswoman yvette clarke          222              lenox road
# 3                               aclu dc          NaN                     NaN
# 4                make the road new york        92-10        roosevelt avenue
# 5                                   NaN          NaN  do the right thing way
# 6                                   NaN          NaN                     NaN
# 7                                   NaN          NaN                     NaN
# 8                            barboncino          781            franklin ave
# 9                                   NaN          103            beal pkwy se
# 10                                  NaN          NaN                canal rd
# 11                                  NaN          123                 main st
# 12                                  NaN          123                 main st
# 13                                  NaN          123                 main st
# 14                                  NaN          123                 main st
# 15                          whole foods          NaN                     NaN
# 16                                  NaN          921               83 street
# 17                                  NaN           30                 w 26 st
# 18                                  NaN           30        west 26th street
# 19                                  NaN           30               w 26th st
#
#             po_box         unit        level staircase           suburb  \
# 0              NaN          NaN          NaN       NaN              NaN
# 1              NaN          NaN    6th floor       NaN              NaN
# 2              NaN        ste 1          NaN       NaN              NaN
# 3   p.o. box 11637          NaN          NaN       NaN              NaN
# 4              NaN          NaN          NaN       NaN  jackson heights
# 5              NaN          NaN          NaN       NaN         bed-stuy
# 6              NaN          NaN          NaN       NaN              NaN
# 7              NaN          NaN          NaN       NaN      fort greene
# 8              NaN          NaN          NaN       NaN    crown heights
# 9              NaN          NaN          NaN       NaN              NaN
# 10             NaN          NaN          NaN       NaN              NaN
# 11             NaN        # 456          NaN       NaN              NaN
# 12             NaN      apt 456          NaN       NaN              NaN
# 13             NaN     apt #456          NaN       NaN              NaN
# 14             NaN  apt no. 456          NaN       NaN              NaN
# 15             NaN          NaN          NaN       NaN              NaN
# 16             NaN          NaN          NaN       NaN              NaN
# 17             NaN          NaN          NaN       NaN              NaN
# 18             NaN          NaN  sixth floor       NaN              NaN
# 19             NaN          NaN       6th fl       NaN              NaN
#
#    city_district             city state_district     state postcode  \
# 0       brooklyn              NaN            NaN      n.y.    11216
# 1       brooklyn              NaN            NaN       NaN    11201
# 2       brooklyn              NaN            NaN  new york    11226
# 3            NaN       washington            NaN        dc    20008
# 4         queens              NaN            NaN       NaN    11372
# 5             bk              NaN            NaN       NaN      NaN
# 6            NaN              NaN            NaN       NaN      NaN
# 7       brooklyn              NaN            NaN       NaN      NaN
# 8       brooklyn              nyc            NaN        ny    11216
# 9            NaN  ft walton beach            NaN        fl      NaN
# 10           NaN          deltona            NaN        fl      NaN
# 11           NaN          oakland            NaN        ca    94789
# 12           NaN          oakland            NaN        ca    94789
# 13           NaN          oakland            NaN        ca    94789
# 14           NaN          oakland            NaN        ca    94789
# 15           NaN              nyc            NaN       NaN      NaN
# 16           NaN              nyc            NaN       NaN      NaN
# 17           NaN              NaN            NaN       NaN      NaN
# 18           NaN              NaN            NaN       NaN      NaN
# 19           NaN              NaN            NaN       NaN      NaN
#
#           country world_region     category     near country_code     source
# 0             NaN          NaN          NaN      NaN           us  libpostal
# 1             NaN          NaN          NaN      NaN           us  libpostal
# 2             NaN          NaN          NaN      NaN           us  libpostal
# 3   united states          NaN          NaN      NaN           us  libpostal
# 4             NaN          NaN          NaN      NaN           us  libpostal
# 5             NaN          NaN          NaN      NaN           us  libpostal
# 6             NaN          NaN  book stores  near me           us  libpostal
# 7             NaN          NaN     theatres       in           us  libpostal
# 8             usa          NaN          NaN      NaN           us  libpostal
# 9             NaN          NaN          NaN      NaN           us  libpostal
# 10            NaN          NaN          NaN      NaN           us  libpostal
# 11            NaN          NaN          NaN      NaN           us  libpostal
# 12            NaN          NaN          NaN      NaN           us  libpostal
# 13            NaN          NaN          NaN      NaN           us  libpostal
# 14            NaN          NaN          NaN      NaN           us  libpostal
# 15            NaN          NaN          NaN      NaN           us  libpostal
# 16            NaN          NaN          NaN      NaN           us  libpostal
# 17            NaN          NaN          NaN      NaN           us  libpostal
# 18            NaN          NaN          NaN      NaN           us  libpostal
# 19            NaN          NaN          NaN      NaN           us  libpostal

# %% [markdown]
# # Senzing Model Performance Improvements by Country
#
# The Senzing model performance improvements are published in Markdown format, which can be read as CSV by Pandas.

# %%
perf_df = pd.read_csv("https://raw.githubusercontent.com/Senzing/libpostal-data/main/files/stats/v1/Parsing_comparison.md", delimiter="|")

# Drop unnamed columns from Markdown pipes
perf_df = perf_df.loc[:, ~perf_df.columns.str.contains('^Unnamed')]

# Replace the --- for nulls with None
perf_df = perf_df.replace("---", None)

# Make all columns after country code floats
perf_df.iloc[:, 1:] = perf_df.iloc[:, 1:].astype(float)

# Sort the table to show largest improvement per country
perf_df = perf_df.sort_values(by="% improvement", ascending=False)

# 27 countries have a 10% or greater accuracy improvement
perf_df.head(27)
# Out:
#    Country % improvement Total records Failures - default libpostal  \
# 45      kr         86.52          51.0                         48.0
# 42      jm          82.4          50.0                         45.0
# 24      eg          82.0          50.0                         50.0
# 1       ae          74.0          50.0                         47.0
# 43      jp          56.4          50.0                         32.0
# 6       az          46.0          50.0                         30.0
# 79      tw         45.76         177.0                        175.0
# 60      pe          38.0          50.0                         24.0
# 64      pr          26.0          50.0                         50.0
# 68      rs          26.0          50.0                         15.0
# 34      hu         24.75         101.0                         29.0
# 17      co         24.56          57.0                         29.0
# 77      tr          22.0          50.0                         43.0
# 35      id          20.0          50.0                         40.0
# 75      sr          18.0          50.0                          9.0
# 76      tj          18.0          50.0                         26.0
# 39      in          18.0          50.0                         42.0
# 15      cl          18.0          50.0                         43.0
# 54      mx         16.36          55.0                         37.0
# 87      za         15.69          51.0                         25.0
# 85      vn          14.0          50.0                         38.0
# 3       ar         13.34          75.0                         26.0
# 2       am          12.0          50.0                          9.0
# 38      im          12.0          50.0                         33.0
# 62      pk          12.0          50.0                         44.0
# 18      cy          10.0          50.0                         43.0
# 22      ec          10.0          50.0                         19.0
#
#    Percent failed - default libposta Failures - Senzing  \
# 45                             94.12               37.0
# 42                              90.0               33.0
# 24                             100.0                9.0
# 1                               94.0               10.0
# 43                              64.0               33.0
# 6                               60.0                7.0
# 79                             98.87               94.0
# 60                              48.0                5.0
# 64                             100.0               37.0
# 68                              30.0                2.0
# 34                             28.71                4.0
# 17                             50.88               15.0
# 77                              86.0               32.0
# 35                              80.0               30.0
# 75                              18.0                0.0
# 76                              52.0               17.0
# 39                              84.0               33.0
# 15                              86.0               34.0
# 54                             67.27               28.0
# 87                             49.02               17.0
# 85                              76.0               31.0
# 3                              34.67               16.0
# 2                               18.0                3.0
# 38                              66.0               27.0
# 62                              88.0               38.0
# 18                              86.0               38.0
# 22                              38.0               14.0
#
#    Percent_failed - Senzing
# 45                    72.55
# 42                     66.0
# 24                     18.0
# 1                      20.0
# 43                     66.0
# 6                      14.0
# 79                    53.11
# 60                     10.0
# 64                     74.0
# 68                      4.0
# 34                     3.96
# 17                    26.32
# 77                     64.0
# 35                     60.0
# 75                      0.0
# 76                     34.0
# 39                     66.0
# 15                     68.0
# 54                    50.91
# 87                    33.33
# 85                     62.0
# 3                     21.33
# 2                       6.0
# 38                     54.0
# 62                     76.0
# 18                     76.0
# 22                     28.0
